# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data = "https://www.youtube.com/watch?v=bU4saR_oI8Q"

filename = "My_QR_CODE.png"

image = qrcode.make(data)

image. save(filename)
plt.imshow(image, cmap='gray')
